# %%
import pandas as pd


df = pd.read_csv("merged_data_updated.csv", parse_dates=["date"])  


train_start, train_end = "2013-07-01", "2017-07-31"
val_start,   val_end   = "2017-08-01", "2018-07-31"
test_start,  test_end  = "2018-08-01", "2019-07-31"


train_df = df[(df["date"] >= train_start) & (df["date"] <= train_end)].copy()
val_df   = df[(df["date"] >= val_start)   & (df["date"] <= val_end)].copy()
test_df  = df[(df["date"] >= test_start)  & (df["date"] <= test_end)].copy()


print("Train rows:", len(train_df))
print("Validation rows:", len(val_df))
print("Test rows:", len(test_df))

print("\n First rows Testset:")
print(test_df.head())
# Out:
# Train rows: 7493
# Validation rows: 1841
# Test rows: 1830
#
#  First rows Testset:
#            date  warengruppe  umsatz  Bewoelkung  Temperatur  \
# 9334 2018-08-01            1     NaN         0.0     23.7625
# 9335 2018-08-01            2     NaN         0.0     23.7625
# 9336 2018-08-01            3     NaN         0.0     23.7625
# 9337 2018-08-01            4     NaN         0.0     23.7625
# 9338 2018-08-01            5     NaN         0.0     23.7625
#
#       Windgeschwindigkeit  Wettercode  KielerWoche
# 9334                 10.0         0.0          NaN
# 9335                 10.0         0.0          NaN
# 9336                 10.0         0.0          NaN
# 9337                 10.0         0.0          NaN
# 9338                 10.0         0.0          NaN
